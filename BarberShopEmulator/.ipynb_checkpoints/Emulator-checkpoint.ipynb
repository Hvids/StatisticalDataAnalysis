# %%
import sys
sys.path.append('./')

# %%
from BarberShop import BarberShop
from Hairdresser import Hairdresser, Hairdressers
from Work import Worker

mean_time_wait_client = 5
time_period = 30
time_works = [29, 30, 15]

barber = BarberShop(mean_time_wait_client, time_period)
for time_work in time_works:
    barber.add_hairdresser(Hairdresser(time_work))

worker = Worker(barber)
worker.work()
worker.report
# Out:
#      time hairdresser 1 hairdresser 2 hairdresser 3 queue
# 0   10:00      Свободен      Свободен      Свободен     0
# 1   10:03      Свободен         Занят      Свободен     0
# 2   10:15         Занят         Занят      Свободен     0
# 3   10:20         Занят         Занят         Занят     0
# 4   10:24         Занят         Занят         Занят     1
# 5   10:24         Занят         Занят         Занят     2
# 6   10:34         Занят         Занят         Занят     3
# 7   10:38         Занят         Занят         Занят     4
# 8   10:41         Занят         Занят         Занят     5
# 9   10:41         Занят         Занят         Занят     4
# 10  10:45         Занят         Занят         Занят     5
# 11  10:47         Занят         Занят         Занят     4
# 12  10:47         Занят         Занят         Занят     5
# 13  10:56         Занят         Занят         Занят     4
# 14  11:06         Занят         Занят         Занят     3
# 15  11:12         Занят         Занят         Занят     2
# 16  11:17         Занят         Занят         Занят     1
# 17  11:28         Занят         Занят         Занят     0
# 18  11:48         Занят      Свободен         Занят     0
# 19  11:53         Занят      Свободен      Свободен     0
# 20  12:07      Свободен      Свободен      Свободен     0
