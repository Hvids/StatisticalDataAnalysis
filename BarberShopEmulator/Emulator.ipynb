# %%
import sys
sys.path.append('./')

# %%
from BarberShop import BarberShop
from Hairdresser import Hairdresser, Hairdressers
from Work import Worker

mean_time_wait_client = 20
time_period = 180
time_works = [29, 30, 15]

barber = BarberShop(mean_time_wait_client, time_period)
for time_work in time_works:
    barber.add_hairdresser(Hairdresser(time_work))

worker = Worker(barber)
worker.work()
worker.report
# Out:
#      time hairdresser 1 hairdresser 2 hairdresser 3 queue
# 0   10:00      Свободен      Свободен      Свободен     0
# 1   10:12         Занят      Свободен      Свободен     0
# 2   10:42         Занят      Свободен         Занят     0
# 3   10:52      Свободен      Свободен         Занят     0
# 4   10:56         Занят      Свободен         Занят     0
# 5   11:06         Занят      Свободен      Свободен     0
# 6   11:11         Занят         Занят      Свободен     0
# 7   11:34         Занят         Занят         Занят     0
# 8   11:50         Занят      Свободен         Занят     0
# 9   11:55         Занят      Свободен      Свободен     0
# 10  11:59         Занят         Занят      Свободен     0
# 11  12:03      Свободен         Занят      Свободен     0
# 12  12:04         Занят         Занят      Свободен     0
# 13  12:14         Занят         Занят         Занят     0
# 14  12:28         Занят         Занят         Занят     1
# 15  12:33         Занят         Занят         Занят     0
# 16  12:34      Свободен         Занят         Занят     0
# 17  12:44         Занят         Занят         Занят     0
# 18  12:46         Занят         Занят         Занят     1
# 19  12:47         Занят         Занят         Занят     2
# 20  12:49         Занят         Занят         Занят     1
# 21  13:05         Занят         Занят         Занят     0
# 22  13:10         Занят         Занят      Свободен     0
# 23  13:14      Свободен         Занят      Свободен     0
# 24  13:49      Свободен      Свободен      Свободен     0
