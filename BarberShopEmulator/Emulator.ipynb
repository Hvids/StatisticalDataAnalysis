# %%
import sys
sys.path.append('./')

# %% [markdown]
# ## Параметры для изменения
# * **mean_time_wait** - среденне время ожидания нового клиента
# * **time_work_barber_shop_period** - период за который смотртся
# * **time_work_hairdressers** - список средних времен работы парикхмахеров

# %%
from BarberShop import BarberShop
from Hairdresser import Hairdresser, Hairdressers
from Work import Worker

# %%
mean_time_wait =5
time_work_barber_shop_period = 180
time_work_hairdressers = [29, 30, 15]

# %%
barber = BarberShop.create_with_hairdressers(
    mean_time_wait, 
    time_work_barber_shop_period, 
    time_work_hairdressers
)
worker = Worker(barber)
worker.work()
worker.report
# Out:
#      time hairdresser 1 hairdresser 2 hairdresser 3 queue
# 0   10:00      Свободен      Свободен      Свободен     0
# 1   10:03         Занят      Свободен      Свободен     0
# 2   10:10         Занят         Занят      Свободен     0
# 3   10:11         Занят         Занят         Занят     0
# 4   10:12         Занят         Занят         Занят     1
# 5   10:20         Занят         Занят         Занят     2
# 6   10:21         Занят         Занят         Занят     3
# 7   10:24         Занят         Занят         Занят     4
# 8   10:29         Занят         Занят         Занят     5
# 9   10:44         Занят         Занят         Занят     6
# 10  10:44         Занят         Занят         Занят     7
# 11  10:44         Занят         Занят         Занят     8
# 12  10:47         Занят         Занят         Занят     7
# 13  10:48         Занят         Занят         Занят     8
# 14  10:50         Занят         Занят         Занят     9
# 15  10:52         Занят         Занят         Занят    10
# 16  10:54         Занят         Занят         Занят    11
# 17  10:55         Занят         Занят         Занят    12
# 18  10:57         Занят         Занят         Занят    11
# 19  11:03         Занят         Занят         Занят    10
# 20  11:16         Занят         Занят         Занят    11
# 21  11:19         Занят         Занят         Занят    12
# 22  11:21         Занят         Занят         Занят    13
# 23  11:24         Занят         Занят         Занят    14
# 24  11:27         Занят         Занят         Занят    15
# 25  11:28         Занят         Занят         Занят    14
# 26  11:28         Занят         Занят         Занят    15
# 27  11:32         Занят         Занят         Занят    16
# 28  11:43         Занят         Занят         Занят    15
# 29  11:43         Занят         Занят         Занят    16
# ..    ...           ...           ...           ...   ...
# 45  12:54         Занят         Занят         Занят    26
# 46  12:59         Занят         Занят         Занят    25
# 47  13:30         Занят         Занят         Занят    24
# 48  13:33         Занят         Занят         Занят    23
# 49  13:46         Занят         Занят         Занят    22
# 50  14:13         Занят         Занят         Занят    21
# 51  14:29         Занят         Занят         Занят    20
# 52  14:30         Занят         Занят         Занят    19
# 53  14:39         Занят         Занят         Занят    18
# 54  14:46         Занят         Занят         Занят    17
# 55  15:18         Занят         Занят         Занят    16
# 56  15:33         Занят         Занят         Занят    15
# 57  15:36         Занят         Занят         Занят    14
# 58  15:42         Занят         Занят         Занят    13
# 59  16:12         Занят         Занят         Занят    12
# 60  16:13         Занят         Занят         Занят    11
# 61  16:41         Занят         Занят         Занят    10
# 62  16:47         Занят         Занят         Занят     9
# 63  16:58         Занят         Занят         Занят     8
# 64  17:08         Занят         Занят         Занят     7
# 65  17:37         Занят         Занят         Занят     6
# 66  17:50         Занят         Занят         Занят     5
# 67  17:55         Занят         Занят         Занят     4
# 68  18:25         Занят         Занят         Занят     3
# 69  18:37         Занят         Занят         Занят     2
# 70  19:00         Занят         Занят         Занят     1
# 71  19:15         Занят         Занят         Занят     0
# 72  19:24         Занят      Свободен         Занят     0
# 73  19:31         Занят      Свободен      Свободен     0
# 74  19:41      Свободен      Свободен      Свободен     0
#
# [75 rows x 5 columns]
