# %%
import sys
sys.path.append('./')

# %%
from BarberShop import BarberShop
from Hairdresser import Hairdresser, Hairdressers
from Work import Worker

mean_time_wait_client = 20
time_period = 180
time_works = [29, 30, 15]

barber = BarberShop(mean_time_wait_client, time_period)
for time_work in time_works:
    barber.add_hairdresser(Hairdresser(time_work))

worker = Worker(barber)
worker.work()
worker.report
# Out:
#      time hairdresser 1 hairdresser 2 hairdresser 3 queue
# 0   10:00      Свободен      Свободен      Свободен     0
# 1   10:25      Свободен      Свободен         Занят     0
# 2   11:05      Свободен         Занят         Занят     0
# 3   11:24      Свободен         Занят      Свободен     0
# 4   12:11      Свободен      Свободен      Свободен     0
# 5   12:24      Свободен      Свободен         Занят     0
# 6   12:55      Свободен      Свободен      Свободен     0
# 7   13:02      Свободен      Свободен         Занят     0
# 8   13:05         Занят      Свободен         Занят     0
# 9   13:30         Занят      Свободен      Свободен     0
# 10  13:31         Занят      Свободен         Занят     0
# 11  13:42      Свободен      Свободен         Занят     0
# 12  13:46      Свободен      Свободен      Свободен     0
# 13  13:49      Свободен      Свободен         Занят     0
# 14  13:49      Свободен         Занят         Занят     0
# 15  14:10         Занят         Занят         Занят     0
# 16  14:18         Занят         Занят      Свободен     0
# 17  14:25         Занят         Занят         Занят     0
# 18  14:33         Занят      Свободен         Занят     0
# 19  14:43         Занят         Занят         Занят     0
# 20  14:46         Занят         Занят      Свободен     0
# 21  15:43      Свободен         Занят      Свободен     0
# 22  16:22      Свободен      Свободен      Свободен     0

# %%
60%60
# Out:
# 0
